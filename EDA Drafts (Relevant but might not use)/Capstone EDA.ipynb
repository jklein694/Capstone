# %% [markdown]
# ### API: 8b7ca752fb7621473d02a6181e3c6227e6609e22

# %% [markdown]
# https://www.census.gov/programs-surveys/sbo/about.html
# https://www.census.gov/programs-surveys/sbo/data.html
# https://www.buzzfeed.com/coralewis/in-5-years-new-york-lost-30-of-its-black-owned-businesses
# https://twitter.com/cora

# %%
key = '8b7ca752fb7621473d02a6181e3c6227e6609e22'

# %%
import requests

# %%
import imports

# %%
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 12, 4
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
import eda
import eda_df


plt.style.use('fivethirtyeight')
# plt.style.use('ggplot')

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
% load_ext giphy_magic
# Out:
# The giphy_magic extension is already loaded. To reload it, use:
#   %reload_ext giphy_magic

# %%
api_request_summary = ['http://api.census.gov/data/2012/sbo?get=NAICS2012_TTL,GEO_TTL,RCPSZFI,RCPSZFI_TTL,FIRMPDEMP&for=us:*&key='+ key,
'http://api.census.gov/data/2012/sbo?get=NAICS2012_TTL,GEO_TTL,RCPSZFI,RCPSZFI_TTL,FIRMPDEMP&for=us:00&key=' + key,
'http://api.census.gov/data/2012/sbo?get=NAICS2012_TTL,GEO_TTL,RCPSZFI,RCPSZFI_TTL,FIRMPDEMP&for=state:*&key=' + key,
'http://api.census.gov/data/2012/sbo?get=NAICS2012_TTL,GEO_TTL,RCPSZFI,RCPSZFI_TTL,FIRMPDEMP&for=state:01&key=' + key,
'http://api.census.gov/data/2012/sbo?get=NAICS2012_TTL,GEO_TTL,RCPSZFI,RCPSZFI_TTL,FIRMPDEMP&for=county:*&key=' + key,
'http://api.census.gov/data/2012/sbo?get=NAICS2012_TTL,GEO_TTL,RCPSZFI,RCPSZFI_TTL,FIRMPDEMP&for=county:*&in=state:*&key=' + key,
'http://api.census.gov/data/2012/sbo?get=NAICS2012_TTL,GEO_TTL,RCPSZFI,RCPSZFI_TTL,FIRMPDEMP&for=county:195&in=state:02&key=' + key,
'http://api.census.gov/data/2012/sbo?get=NAICS2012_TTL,GEO_TTL,RCPSZFI,RCPSZFI_TTL,FIRMPDEMP&for=place:*&key=' + key,
'http://api.census.gov/data/2012/sbo?get=NAICS2012_TTL,GEO_TTL,RCPSZFI,RCPSZFI_TTL,FIRMPDEMP&for=place:*&in=state:*&key=' + key,
'http://api.census.gov/data/2012/sbo?get=NAICS2012_TTL,GEO_TTL,RCPSZFI,RCPSZFI_TTL,FIRMPDEMP&for=place:98013&in=state:02&key=' + key,
'http://api.census.gov/data/2012/sbo?get=NAICS2012_TTL,GEO_TTL,RCPSZFI,RCPSZFI_TTL,FIRMPDEMP&for=combined+statistical+area:*&key=' + key,
'http://api.census.gov/data/2012/sbo?get=NAICS2012_TTL,GEO_TTL,RCPSZFI,RCPSZFI_TTL,FIRMPDEMP&for=combined+statistical+area:147&key=' + key,
'http://api.census.gov/data/2012/sbo?get=NAICS2012_TTL,GEO_TTL,RCPSZFI,RCPSZFI_TTL,FIRMPDEMP&for=metropolitan+statistical+area/micropolitan+statistical+area:*&key=' + key,
'http://api.census.gov/data/2012/sbo?get=NAICS2012_TTL,GEO_TTL,RCPSZFI,RCPSZFI_TTL,FIRMPDEMP&for=metropolitan+statistical+area/micropolitan+statistical+area:36300&key=' + key,]

# %%
# Make a get request to get the latest position of the international space station from the opennotify api.
response = requests.get("https://api.census.gov/data/2012/sbo?get=FIRMALL,NAICS2012_TTL,GEO_TTL,EMPSZFI,EMPSZFI_TTL&for=us:*&key=8b7ca752fb7621473d02a6181e3c6227e6609e22")

# Print the status code of the response.
print(response.status_code)
# Out:
# 200

# %%
data_name = []
for n in range(len(api_request_summary)):
    data = 'data{}'.format(n)
    data_name.append(data)

# %%
data_summary = []
for n, html in enumerate(api_request_summary):
    response = requests.get(html)
    print(response.status_code)
    json = response.json()
    data_summary.append(pd.DataFrame(json[1:], columns=json[0]))
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
data_summary[0].head()
# Out:
#            NAICS2012_TTL        GEO_TTL RCPSZFI  \
# 0  Total for all sectors  United States     001
# 1  Total for all sectors  United States     511
# 2  Total for all sectors  United States     518
# 3  Total for all sectors  United States     519
# 4  Total for all sectors  United States     521
#
#                                        RCPSZFI_TTL FIRMPDEMP  us
# 0                                        All firms   5424458  00
# 1    Firms with sales/receipts of less than $5,000     35242  00
# 2    Firms with sales/receipts of $5,000 to $9,999     55678  00
# 3  Firms with sales/receipts of $10,000 to $24,999    165176  00
# 4  Firms with sales/receipts of $25,000 to $49,999    273794  00

# %%
data_summary[1].head()
# Out:
#            NAICS2012_TTL        GEO_TTL RCPSZFI  \
# 0  Total for all sectors  United States     001
# 1  Total for all sectors  United States     511
# 2  Total for all sectors  United States     518
# 3  Total for all sectors  United States     519
# 4  Total for all sectors  United States     521
#
#                                        RCPSZFI_TTL FIRMPDEMP  us
# 0                                        All firms   5424458  00
# 1    Firms with sales/receipts of less than $5,000     35242  00
# 2    Firms with sales/receipts of $5,000 to $9,999     55678  00
# 3  Firms with sales/receipts of $10,000 to $24,999    165176  00
# 4  Firms with sales/receipts of $25,000 to $49,999    273794  00

# %%
data_summary[2].head()
# Out:
#            NAICS2012_TTL  GEO_TTL RCPSZFI  \
# 0  Total for all sectors  Alabama     001
# 1  Total for all sectors  Alabama     511
# 2  Total for all sectors  Alabama     518
# 3  Total for all sectors  Alabama     519
# 4  Total for all sectors  Alabama     521
#
#                                        RCPSZFI_TTL FIRMPDEMP state
# 0                                        All firms     67449    01
# 1    Firms with sales/receipts of less than $5,000       356    01
# 2    Firms with sales/receipts of $5,000 to $9,999       533    01
# 3  Firms with sales/receipts of $10,000 to $24,999      1453    01
# 4  Firms with sales/receipts of $25,000 to $49,999      2843    01

# %%
data_summary[3].head()
# Out:
#            NAICS2012_TTL  GEO_TTL RCPSZFI  \
# 0  Total for all sectors  Alabama     001
# 1  Total for all sectors  Alabama     511
# 2  Total for all sectors  Alabama     518
# 3  Total for all sectors  Alabama     519
# 4  Total for all sectors  Alabama     521
#
#                                        RCPSZFI_TTL FIRMPDEMP state
# 0                                        All firms     67449    01
# 1    Firms with sales/receipts of less than $5,000       356    01
# 2    Firms with sales/receipts of $5,000 to $9,999       533    01
# 3  Firms with sales/receipts of $10,000 to $24,999      1453    01
# 4  Firms with sales/receipts of $25,000 to $49,999      2843    01

# %%
data_summary[4].head()
# Out:
#            NAICS2012_TTL         GEO_TTL RCPSZFI RCPSZFI_TTL FIRMPDEMP state  \
# 0  Total for all sectors  Autauga County     001   All firms       749    01
# 1  Total for all sectors  Baldwin County     001   All firms      3951    01
# 2  Total for all sectors  Barbour County     001   All firms       434    01
# 3  Total for all sectors     Bibb County     001   All firms       251    01
# 4  Total for all sectors   Blount County     001   All firms       640    01
#
#   county
# 0    001
# 1    003
# 2    005
# 3    007
# 4    009

# %%
data_summary[5].head()
# Out:
#            NAICS2012_TTL         GEO_TTL RCPSZFI RCPSZFI_TTL FIRMPDEMP state  \
# 0  Total for all sectors  Autauga County     001   All firms       749    01
# 1  Total for all sectors  Baldwin County     001   All firms      3951    01
# 2  Total for all sectors  Barbour County     001   All firms       434    01
# 3  Total for all sectors     Bibb County     001   All firms       251    01
# 4  Total for all sectors   Blount County     001   All firms       640    01
#
#   county
# 0    001
# 1    003
# 2    005
# 3    007
# 4    009

# %%
data_summary[6].head()
# Out:
#            NAICS2012_TTL                 GEO_TTL RCPSZFI RCPSZFI_TTL  \
# 0  Total for all sectors  Petersburg Census Area     001   All firms
#
#   FIRMPDEMP state county
# 0       163    02    195

# %%
data_summary[7].head()
# Out:
#            NAICS2012_TTL          GEO_TTL RCPSZFI RCPSZFI_TTL FIRMPDEMP state  \
# 0  Total for all sectors        Arab city     001   All firms       205    01
# 1  Total for all sectors        Argo town     001   All firms        55    01
# 2  Total for all sectors  Birmingham city     001   All firms      4972    01
# 3  Total for all sectors        Boaz city     001   All firms       257    01
# 4  Total for all sectors      Calera city     001   All firms       192    01
#
#    place
# 0  02116
# 1  02320
# 2  07000
# 3  07912
# 4  11416

# %%
data_summary[8].head()
# Out:
#            NAICS2012_TTL          GEO_TTL RCPSZFI RCPSZFI_TTL FIRMPDEMP state  \
# 0  Total for all sectors        Arab city     001   All firms       205    01
# 1  Total for all sectors        Argo town     001   All firms        55    01
# 2  Total for all sectors  Birmingham city     001   All firms      4972    01
# 3  Total for all sectors        Boaz city     001   All firms       257    01
# 4  Total for all sectors      Calera city     001   All firms       192    01
#
#    place
# 0  02116
# 1  02320
# 2  07000
# 3  07912
# 4  11416

# %%
data_summary[9].head()
# Out:
#            NAICS2012_TTL                 GEO_TTL RCPSZFI RCPSZFI_TTL  \
# 0  Total for all sectors  Aleutians East Borough     001   All firms
#
#   FIRMPDEMP state  place
# 0        19    02  98013

# %%
data_summary[10].head()
# Out:
#            NAICS2012_TTL                                       GEO_TTL  \
# 0  Total for all sectors   Boise City-Mountain Home-Ontario, ID-OR CSA
# 1  Total for all sectors  Boston-Worcester-Providence, MA-RI-NH-CT CSA
# 2  Total for all sectors            Cape Girardeau-Sikeston, MO-IL CSA
# 3  Total for all sectors   Charleston-Huntington-Ashland, WV-OH-KY CSA
# 4  Total for all sectors                  Charlotte-Concord, NC-SC CSA
#
#   RCPSZFI RCPSZFI_TTL FIRMPDEMP combined statistical area
# 0     001   All firms     14521                       147
# 1     001   All firms    161314                       148
# 2     001   All firms      3083                       164
# 3     001   All firms     10597                       170
# 4     001   All firms     42987                       172

# %%
data_summary[11].head()
# Out:
#            NAICS2012_TTL                                      GEO_TTL RCPSZFI  \
# 0  Total for all sectors  Boise City-Mountain Home-Ontario, ID-OR CSA     001
#
#   RCPSZFI_TTL FIRMPDEMP combined statistical area
# 0   All firms     14521                       147

# %%
data_summary[12].head()
# Out:
#            NAICS2012_TTL                                       GEO_TTL  \
# 0  Total for all sectors  Allentown-Bethlehem-Easton, PA-NJ Metro Area
# 1  Total for all sectors     Augusta-Richmond County, GA-SC Metro Area
# 2  Total for all sectors     Boston-Cambridge-Newton, MA-NH Metro Area
# 3  Total for all sectors              Cape Girardeau, MO-IL Metro Area
# 4  Total for all sectors  Charlotte-Concord-Gastonia, NC-SC Metro Area
#
#   RCPSZFI RCPSZFI_TTL FIRMPDEMP  \
# 0     001   All firms     14608
# 1     001   All firms      7634
# 2     001   All firms     96636
# 3     001   All firms      2373
# 4     001   All firms     40640
#
#   metropolitan statistical area/micropolitan statistical area
# 0                                              10900
# 1                                              12260
# 2                                              14460
# 3                                              16020
# 4                                              16740

# %%
data_summary[13].head()
# Out:
#            NAICS2012_TTL                            GEO_TTL RCPSZFI  \
# 0  Total for all sectors  Ogdensburg-Massena, NY Micro Area     001
#
#   RCPSZFI_TTL FIRMPDEMP  \
# 0   All firms      1369
#
#   metropolitan statistical area/micropolitan statistical area
# 0                                              36300

# %%
# Out:
#            NAICS2012_TTL        GEO_TTL RCPSZFI  \
# 0  Total for all sectors  United States     001
# 1  Total for all sectors  United States     511
# 2  Total for all sectors  United States     518
# 3  Total for all sectors  United States     519
# 4  Total for all sectors  United States     521
#
#                                        RCPSZFI_TTL FIRMPDEMP  us
# 0                                        All firms   5424458  00
# 1    Firms with sales/receipts of less than $5,000     35242  00
# 2    Firms with sales/receipts of $5,000 to $9,999     55678  00
# 3  Firms with sales/receipts of $10,000 to $24,999    165176  00
# 4  Firms with sales/receipts of $25,000 to $49,999    273794  00

# %%
df = pd.DataFrame(data[1:], columns=data[0])

# %%
df.head()
# Out:
#     FIRMALL          NAICS2012_TTL        GEO_TTL EMPSZFI  \
# 0  27626360  Total for all sectors  United States     001
# 1         0  Total for all sectors  United States     611
# 2         0  Total for all sectors  United States     612
# 3         0  Total for all sectors  United States     620
# 4         0  Total for all sectors  United States     630
#
#                      EMPSZFI_TTL  us
# 0                      All firms  00
# 1        Firms with no employees  00
# 2    Firms with 1 to 4 employees  00
# 3    Firms with 5 to 9 employees  00
# 4  Firms with 10 to 19 employees  00

# %%
data_html = 'https://api.census.gov/data/2012/sbo/cscb?get=FIRMALL,FIRMPDEMP_PCT_S,RCPALL,FIRMNOPD_S,RCPNOPD,FIRMNOPD_PCT,FIRMNOPD,EMP_S,PAYANN,RCPPDEMP,RCPPDEMP_F,RCPNOPD_PCT_S,FIRMALL_S,SPOUSES,CBGROUP_TTL,EMP,RCPPDEMP_S,EMP_PCT,YEAR,RCPNOPD_PCT,FIRMNOPD_PCT_S,EMP_PCT_S,CBGROUP,NAICS2012_TTL,PAYANN_PCT_S,PAYANN_S,GEO_TTL,RCPALL_PCT,RCPPDEMP_PCT_S,PAYANN_PCT,SPOUSES_TTL,RCPALL_PCT_S,RCPNOPD_S,FIRMPDEMP_PCT,FIRMPDEMP_S,FIRMPDEMP,FIRMALL_PCT,FIRMALL_PCT_S,RCPPDEMP_PCT&for=us:*&key='+ key

# %%
response = requests.get(data_html)
print(response.status_code)
json = response.json()
data = pd.DataFrame(json[1:], columns=json[0])
# Out:
# 200

# %%
data.head()
# Out:
#     FIRMALL FIRMPDEMP_PCT_S       RCPALL FIRMNOPD_S     RCPNOPD FIRMNOPD_PCT  \
# 0  27626360               0  33536848821        0.1  1041586434            0
# 1   9878397               0   1419834295        0.1   229247857            0
# 2  14844597               0   9466039188        0.1   652640996            0
# 3   2456386               0   1078204389        0.5   117604270            0
# 4   3305873               0    473635944        0.1    93640945            0
#
#    FIRMNOPD EMP_S      PAYANN     RCPPDEMP ... SPOUSES_TTL RCPALL_PCT_S  \
# 0  22201902   0.4  5236446058  32495262387 ...   All firms            0
# 1   8842742   0.8   263720252   1190586438 ...   All firms            0
# 2  11509025   0.9  1643868568   8813398192 ...   All firms            0
# 3   1691409   0.9   188853393    960600118 ...   All firms            0
# 4   3018371   1.1    70855704    379994999 ...   All firms            0
#
# ...
